# %%
import pandas as pd   
import numpy as np  
#import scipy as sp
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import PredefinedSplit
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline


credit_immo=pd.read_csv('credit_immo.csv',sep=',')
iris=pd.read_csv('iris.csv',sep=',')
montant_temps=pd.read_csv('montant_temps.csv',sep=',')
tendance_centrale=pd.read_csv('tendance_centrale.csv',sep=',')
#ventes=pd.read_csv('ventes.csv',sep=',')
d = pd.DataFrame(np.random.randn(6,4),index=['1','3','4','6','7','8'],columns=['taux_de_ventes','croissance_vente','ratio_benefice','ratio_perte'])

d=d.reindex(['1','2','3','4','5','6','7','8'])
print(d)
#null=d.isnull()
#print(null)
#df = pd.DataFrame(d)
nan_replaced = d.replace(np.nan,0)
print(nan_replaced)
d=d.dropna()
d
# Out:
#    taux_de_ventes  croissance_vente  ratio_benefice  ratio_perte
# 1       -0.458807          0.843392       -0.472392    -1.485096
# 2             NaN               NaN             NaN          NaN
# 3       -0.108589         -0.566328       -0.446247    -0.695758
# 4        0.063316          0.200856        0.008202     1.627079
# 5             NaN               NaN             NaN          NaN
# 6        0.330307         -2.459295        0.924918    -1.442617
# 7       -2.146092          0.431401        1.511549     1.175528
# 8        0.964772          0.002097       -0.899253     1.158329
#    taux_de_ventes  croissance_vente  ratio_benefice  ratio_perte
# 1       -0.458807          0.843392       -0.472392    -1.485096
# 2        0.000000          0.000000        0.000000     0.000000
# 3       -0.108589         -0.566328       -0.446247    -0.695758
# 4        0.063316          0.200856        0.008202     1.627079
# ...

# %%
import pandas as pd   
import numpy as np  
#import scipy as sp
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import PredefinedSplit
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder



credit_immo=pd.read_csv('credit_immo.csv',sep=',')

X=credit_immo.iloc[:,-9:-1].values

Y=credit_immo.iloc[:,-1].values


print(X)
impt_mean=SimpleImputer(missing_values=np.nan, strategy='mean')

#Adapter le model aux données
impt_mean.fit(X[:,0:1]) #tu comptes la moyenne de toute les lignes de la colonne Niv_bac sauf les nan
impt_mean.fit(X[:,7:8]) # idem pour la colonne 7 


print(X[:,0:1])
X[:,0:1] = impt_mean.transform(X[:,0:1]) #met la moyenne dans la case vide de la colonne 
print("***************")

print(X[:,0:1])

print("=================================================")
print(X[:,7:8])
X[:,7:8] = impt_mean.transform(X[:,7:8])
print("***************")
print(X[:,7:8])

print("=================================================")
#label encoder.
credit_immo=LabelEncoder()

print(X[:,2])
#Encodage de la colonne 2 du tableau qui est catégorielle --> 3 catégorie donc 1, 2 et 3
X[:,2]=LabEnc_X.fit_transform(X[:,2])
print("***************")
print(X[:,2])
print("**************************************************************")
#standard scaler
#Récupération des données
credit_immo= pd.read_csv('credit_immo.csv',',')
#Récupération des valeurs d'entrées et de sortie
X_credit = credit_immo.iloc[:,-11:-1].values
print(X_credit.shape)
Y_credit = credit_immo.iloc[:,-1].values.reshape(-1,1)
print(Y_credit.shape)
#Séparation en 2 jeux de données
#X_credit_train, X_credit_test, Y_credit_train, Y_credit_test =train_test_split(X_credit, Y_credit, test_size = 0.3, random_state=0)

#X_credit_test = credit.fit_transform(X_credit_test)
print("=====================================")
print(X_credit_test)
# Out:
# [[3.0 45 'CDI' 40000 4000 'M' 0.3 3.0]
#  [5.0 28 'CDI' 30500 1320 'M' 0.1 0.0]
#  [0.0 55 'CDI' 28000 40000 'C' 0.0 0.0]
#  [4.0 23 'CDD' 15000 0 'M' 0.1 nan]
#  [0.0 33 'CDD' 27000 3000 'C' 0.1 2.0]
#  [0.0 41 'INTERIM' 40000 1000 'M' 0.0 4.0]
#  [-1.0 29 'CDI' 50000 3000 'C' 0.0 0.0]
#  [-3.0 24 'INTERIM' 29000 5000 'C' 0.0 0.0]
#  [nan 26 'CDI' 44000 0 'M' 0.1 1.0]
#  [3.0 37 'CDI' 45800 2000 'M' 0.2 2.0]
#  [2.0 40 'CDI' 60000 1500 'M' 0.3 3.0]
#  [0.0 38 'CDD' 26000 8000 'C' 0.4 0.0]
#  [-3.0 39 'INTERIM' 29000 4900 'M' 0.0 1.0]
#  [0.0 31 'CDI' 43000 100000 'M' 0.2 2.0]
#  [1.0 70 'CDD' 45000 17000 'C' 0.3 0.0]
#  [0.0 42 'ENTRPRENEUR' 70000 26000 'M' 0.2 0.0]
#  [8.0 46 'CDI' 80000 8000 'M' 0.0 3.0]
#  [3.0 23 'CDI' 100000 0 'M' 0.3 1.0]
#  [4.0 32 'CDI' 21000 1200 'M' 0.1 2.0]]
# [[3.0]
#  [5.0]
#  [0.0]
#  [4.0]
#  [0.0]
#  [0.0]
#  [-1.0]
#  [-3.0]
#  [nan]
#  [3.0]
#  [2.0]
#  [0.0]
#  [-3.0]
#  [0.0]
#  [1.0]
#  [0.0]
#  [8.0]
#  [3.0]
#  [4.0]]
# ***************
# ...

# %%
   import pandas as pd   
import numpy as np  
#import scipy as sp
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import PredefinedSplit
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline

montant_temps=pd.read_csv('montant_temps.csv',sep=',')
X="Montant_du_capitale"
Y="Temps"
Y = montant_temps.iloc[:,0].values
X = montant_temps.iloc[:,1].values
montant_temps.plot.scatter("Montant_du_capitale", "Temps")
# Out:
# <AxesSubplot:xlabel='Montant_du_capitale', ylabel='Temps'>

# %%
import pandas as pd   
import numpy as np  
#import scipy as sp
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import PredefinedSplit
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder

tendance_centrale=pd.read_csv('tendance_centrale.csv',sep=',')
print(tendance_centrale.mean())

print(tendance_centrale.median())
print(tendance_centrale.mode())
# Out:
# Age       45.647059
# Rating     4.438824
# dtype: float64
# Age       49.0
# Rating     4.3
# dtype: float64
#      Nom   Age  Rating
# 0  perez  53.0    3.78
# 1    NaN   NaN    3.95
# 2    NaN   NaN    4.30
# 3    NaN   NaN    4.80
# 4    NaN   NaN    5.98

# %%
import pandas as pd   
import numpy as np  
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import PredefinedSplit
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline

iris=pd.read_csv('iris.csv',sep=',')
Y = iris.iloc[:,0].values
X = iris.iloc[:,1].values
Z = iris.iloc[:,2].values
size = [100,500,100,500,100,500,100,500]

plt.scatter(x,y,s=size)

plt.title('setosa')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
import pandas as pd   
import numpy as np  
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import PredefinedSplit
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline
from scipy.stats import pearsonr
iris=pd.read_csv('iris.csv',sep=',')

Y = iris.iloc[:,0].values
X = iris.iloc[:,1].values
Z = iris.iloc[:,2].values
coeff_pearson,_ = pearsonr(x,y)
print("coefficient de Pearson = {}".format(coeff_pearson))
# Out:
# coefficient de Pearson = nan
